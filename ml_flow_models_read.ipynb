# %%
import mlflow
import pandas as pd

# %%
from pathlib import Path

uri = "http://127.0.0.1:5000"

mlflow.set_tracking_uri(uri)

# %%
model_name = "random_forest"
model_version = "champion"

model = mlflow.pyfunc.load_model(f"models:/{model_name}@{model_version}")
model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: random_forest
#   flavor: mlflow.sklearn
#   run_id: 22671ac8b3554d58ab0deb71e311e27f

# %%
data_path = '../data/lending_data.csv'
df = pd.read_csv(data_path)

# %%
input_data = df.loc[df["default.payment.next.month"] == 1].sample(10).drop("ID", axis=1)
input_data
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 18421   160000.0    2          2         2   25      1     -1      0      0
# 12369    20000.0    2          2         2   42      2      2      2      2
# 10914   120000.0    1          1         1   45      1     -1      0      0
# 11299   260000.0    2          3         1   41      0      0      0      2
# 1619     90000.0    2          2         2   33      0      0     -1     -1
# 8869    240000.0    1          1         1   44     -1     -1     -1     -1
# 4579    200000.0    1          3         1   50      1      2      2      2
# 17451    70000.0    2          2         2   44      0      0      0     -1
# 15574    50000.0    1          2         1   51      0      0      0      0
# 20660    10000.0    1          3         2   36     -1     -1     -1     -1
#
#        PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 18421      0  ...     3133.0        0.0        0.0    1000.0    1043.0
# 12369      2  ...    19554.0    19795.0    19342.0       0.0    2344.0
# 10914      0  ...   109121.0   109061.0   112079.0  106257.0    5400.0
# 11299      2  ...    88806.0    86858.0    89970.0    5700.0    9000.0
# 1619       0  ...    55970.0    59612.0    40281.0    1000.0    2000.0
# 8869      -1  ...     1473.0     1473.0     1473.0    1473.0    1473.0
# 4579       2  ...   171377.0   163943.0   162195.0       0.0    6998.0
# 17451      0  ...    69385.0    30103.0     3752.0    3100.0    1600.0
# 15574      0  ...    32925.0    26640.0    22247.0    2044.0    2000.0
# 20660      0  ...     6260.0     5990.0     6520.0    4009.0    4011.0
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# 18421    1133.0       0.0       0.0    7482.0                           1
# 12369     800.0     683.0       0.0    1500.0                           1
# 10914    4000.0    3944.0    4817.0    8892.0                           1
# 11299    4500.0       0.0    5000.0    3700.0                           1
# 1619    61000.0    5000.0    1800.0    1200.0                           1
# 8869     1473.0    1473.0    1473.0     390.0                           1
# 4579     4558.0    5921.0    4526.0    5014.0                           1
# 17451   94540.0    1124.0     100.0    3091.0                           1
# 15574    1547.0    2388.0     944.0    1000.0                           1
# 20660    6260.0     120.0    2000.0    2000.0                           1
#
# [10 rows x 24 columns]

# %%
model.predict(input_data.drop("default.payment.next.month", axis=1))
# Out:
# array([0, 1, 0, 0, 0, 1, 0, 0, 0, 0])
